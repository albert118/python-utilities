# %% [markdown]
# # Create Scheduled Automations (Arrears)
#
# ## Caveats:
# Using the SQL option (as would be expected on first time setup), the user cannot construct a valid CSV. This will create a CSV copy of a given table (name) - not what is needed! Ideally this should construct a table with the (valid) columns:
#
#     CustomerId,Username,Pw,MessageTemplateId,AutomationId
#
# Currently, it is preferred to input as CSV (choose 'n' on step 2.) and have a pre-valdiated Message Template ID, CustomerIDs, etc...
#
# ## Prerequisites:
# --------------------
#
# For the sake of simplicity and faster development, each customer:
# *  **SHOULD NOT HAVE AN EXISTING AUTOMATION YET**.
#    * Otherwise an automation will be inserted but the updating of the automation with a schedule may not occur for the one created.
# * have access to a valid messageschedule (template in UI) **or** access to a messagescheduledefault (these work for all customers).
#    * This is set in the CSV data read-in (or SQL).
#
# ## Workflow:
# --------------------
# 1. Set Constants;
# 2. Ask whether to read from db;
#    * (yes) Input csv file name to export data to and eventually also read from;
#      * Add db credentials and server path;
#      * Export read data to a csv file.
#    * (no)  Input csv file name read from (previously exported to from other scripts).
#      * Read from csv file and load customer data into memory.
# 3. Configure API Requests;
#    * Authenticate customers.
# 4. Configure Automation Rules & Schedule;
#
# **Note:** (*Steps 5, 6, and 7* done separately as the current arrears automation UI process does these separately and there is currently no endpoint that inserts with schedule. Inserting also does not return an id).
#
# 5. Insert automations per Customer session;
# 6. Query Automations per customer and obtain their Automation ID for the first Arrears Automation found;
# 7. Update all Automations with a Schedule (configured in step 4).
#
# ~~**Note: Current caveat --> the same message template is being used for all rules.**~~
#
# **Note: A default message template is assigned to all Automations.** This should be fine, as the `messsagescheduledefault` schema is not customerContext bound.

# %%
import pandas as pd
from requests import Session
from tqdm.auto import tqdm

from Auth import UserSessionsHandler
from CommonLib import NotebookHelper, ConsoleHelpers
from CommonLib.ListHelpers import FilterList
from CommonLib.ResponseDecorators import PropertyMeHttpRequestExceptionHandler
from Config import (ConfigureCsvFilename, ConfigurePropertyMeBaseUrl,
                    ConfigureUrl, ConfigureMySqlConnectionString,
                    ConfigureDbTableName)
from Database import *
# Out:
# ------------------------------------------------------
# KeyboardInterrupt    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_50728/3880839500.py in <module>
#       3 from tqdm.auto import tqdm
#       4
# ----> 5 from Auth import UserSessionsHandler
#       6 from CommonLib import NotebookHelper, ConsoleHelpers
#       7 from CommonLib.ListHelpers import FilterList
#
# ~\source\repos\data-tools\python-http-tools\Auth\__init__.py in <module>
#      10 """
#      11
# ---> 12 from .AuthenticateUsers import AuthenticateUsers
#      13 from .UserSession import UserSession
#      14 from .UserSessionsHandler import UserSessionsHandler
#
# ~\source\repos\data-tools\python-http-tools\Auth\AuthenticateUsers.py in <module>
#       9 """
#      10
# ---> 11 from .UserSessionsHandler import UserSessionsHandler
#      12
#      13 def AuthenticateUsers(customers: list, baseUrl: str, pauseOnCompletion=False) -> list:
#
# ~\source\repos\data-tools\python-http-tools\Auth\UserSessionsHandler.py in <module>
#       9 """
#      10
# ---> 11 from CommonLib.ListHelpers import FilterList
#      12 from .UserSession import UserSession
#      13
#
# ~\source\repos\data-tools\python-http-tools\CommonLib\__init__.py in <module>
#      14 from .Time import *
#      15 from .NotebookHelper import *
# ---> 16 from .Stats import *
#
# ~\source\repos\data-tools\python-http-tools\CommonLib\Stats.py in <module>
#       9
#      10 import numpy as np
# ---> 11 import seaborn as sns
#      12 from matplotlib import pyplot as plt
#      13 from pandas import DataFrame, Series
#
# ~\source\repos\data-tools\python-http-tools\lib\site-packages\seaborn\__init__.py in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#       5 from .relational import *  # noqa: F401,F403
#
# ~\source\repos\data-tools\python-http-tools\lib\site-packages\seaborn\rcmod.py in <module>
#       5 import matplotlib as mpl
#       6 from cycler import cycler
# ----> 7 from . import palettes
#       8
#       9
#
# ~\source\repos\data-tools\python-http-tools\lib\site-packages\seaborn\palettes.py in <module>
#       7 from .external import husl
#       8
# ----> 9 from .utils import desaturate, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      11
#
# ~\source\repos\data-tools\python-http-tools\lib\site-packages\seaborn\utils.py in <module>
#       8
#       9 import numpy as np
# ---> 10 from scipy import stats
#      11 import pandas as pd
#      12 import matplotlib as mpl
#
# ~\source\repos\data-tools\python-http-tools\lib\site-packages\scipy\stats\__init__.py in <module>
#     439 """
#     440
# --> 441 from .stats import *
#     442 from .distributions import *
#     443 from .morestats import *
#
# ~\source\repos\data-tools\python-http-tools\lib\site-packages\scipy\stats\stats.py in <module>
#      35 from numpy import array, asarray, ma
#      36
# ---> 37 from scipy.spatial.distance import cdist
#      38 from scipy.ndimage import measurements
#      39 from scipy._lib._util import (check_random_state, MapWrapper,
#
# ~\source\repos\data-tools\python-http-tools\lib\site-packages\scipy\spatial\__init__.py in <module>
#     100 from ._plotutils import *
#     101 from ._procrustes import procrustes
# --> 102 from ._geometric_slerp import geometric_slerp
#     103
#     104 __all__ = [s for s in dir() if not s.startswith('_')]
#
# ~\source\repos\data-tools\python-http-tools\lib\site-packages\scipy\spatial\_geometric_slerp.py in <module>
#       6
#       7 import numpy as np
# ----> 8 from scipy.spatial.distance import euclidean
#       9
#      10
#
# ~\source\repos\data-tools\python-http-tools\lib\site-packages\scipy\spatial\distance.py in <module>
#     120
#     121 from . import _distance_wrap
# --> 122 from . import _hausdorff
#     123 from ..linalg import norm
#     124 from ..special import rel_entr
#
# C:\Python39\lib\importlib\_bootstrap.py in parent(self)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 1. Set Constants
# --------------------

# %%
baseUrl = ConfigurePropertyMeBaseUrl()
queryAutomationUrl = baseUrl + '/api/automation/automations?Type=Arrears'
createAutomationUrl = baseUrl + '/api/automation/automations'
patchAutomationEndpointUrl = baseUrl + '/api/automation/automations'

divider = "********************************************************************************"
createAutomationData = { "Type": "Arrears", "Name": "Load Test Automation", "IsActive": True }

fullFilenameDefault = '2021-10-25_DEV2_deepuser-data'
fullFilename = None
dbString = None

# MemberId isnt needed in this workflow, but keeping it here to not overwrite old data
customers = pd.DataFrame()

# %% [markdown]
# ## 2. Set Datasource
# --------------------

# %%
# Retrieve the load testing customer data
print(divider)

csvExplanation = """
    The csv will require columns titled: CustomerId, Username, Pw, MessageTemplateId
    If these values are missing, then subsequent operations may fail unexpectedly.
    """
print("\n== CONFIGURING CSV ==")
print(csvExplanation)

fullFilename = ConfigureCsvFilename(fullFilenameDefault)

# Read from csv (expecting 4 columns)
print('\nREADING FROM CSV TO LOAD CUSTOMER DATA:')
customers = pd.read_csv(fullFilename)
print('\nCustomer rows from file (customerId, username, messageTemplateId, memberId, managerId) (Password not shown):')
NotebookHelper.Output(customers.drop(["Pw"], axis=1).head())

print(divider)

# %%
# the wide test user
wideUser = (pd
    .read_csv(fullFilename)
    .drop(["Unnamed: 0"], axis=1, errors='ignore')
)

# propogate customerWide across the all of the wide automations.
customerWide = (pd
    .read_csv(ConfigureCsvFilename("deepuser-aa-load-test-inserted-automations-for-{CUSTOMER_ID_HERE}"))
    .assign(CustomerId=wideUser.CustomerId.values[0])
    .assign(Username=wideUser.Username.values[0])
    .assign(Pw=wideUser.Pw.values[0])
    .assign(MessageTemplateId=wideUser.MessageTemplateId.values[0])
    .assign(MemberId=wideUser.MemberId.values[0])
)
# Out:
# Enter the csv filename (exclude the .csv extension suffix. Enter no value to default to "deepuser-aa-load-test-inserted-automations-for-{CUSTOMER_ID_HERE}"):  2021-10-25_DEV2_wide-automations-for-adcc00f4-f7b3-4079-a1aa-250e7e864504
# The full filename will be "2021-10-25_DEV2_wide-automations-for-adcc00f4-f7b3-4079-a1aa-250e7e864504.csv"

# %% [markdown]
# ## 3. Configure API Requests
# --------------------

# %%
# Configure the load testing 'customer' authentication sessions.
print(divider)
print('\nAUTHENTICATING AND OBTAINING SESSION DATA FOR EACH CUSTOMER:')

def MakeSession(s: pd.Series, handler: UserSessionsHandler):
    """Functional approach is a neat way to easily auth users in a dataframe."""
    return handler.AddUserSession(s.Username, s.Pw, customerId=s.CustomerId)

pmeHandler = UserSessionsHandler(baseUrl)
customers.apply(lambda c: MakeSession(c, pmeHandler), axis=1)
pmeHandler.AuthenticateSessions()

print('\n\n**CHECK CUSTOMER DATA IS ALL EXPECTED**')
print(f"{len(pmeHandler.Sessions)} sessions were created.")
print(f"Session summary:\t{pmeHandler.Sessions[:5]}")
endSectionMessage = "To re-execute the script and start again, close the program."
ConsoleHelpers.PreventImmediateConsoleClose(endSectionMessage)

print(divider)
# Out:
# ********************************************************************************
#
# AUTHENTICATING AND OBTAINING SESSION DATA FOR EACH CUSTOMER:
# Authenticating for deeptest_aaloadtestinguser@propertyme.com
#
#
# **CHECK CUSTOMER DATA IS ALL EXPECTED**
# 1 sessions were created.
# Session summary:	[Login: deeptest_aaloadtestinguser@propertyme.com | IsAuthenticated: True]
#
#
# To re-execute the script and start again, close the program.
# Hit "Enter" with no value to close console.
# ********************************************************************************

# %% [markdown]
# ## 4. Configure Automation Rules & Schedule
# ------------------

# %%
# Setup automation rules and schedules
print(divider)
print('\nCONFIGURE AUTOMATION RULES AND SCHEDULES:')

# Setup weekdays for schedule to occur
while True:
    useAllWeekdays = input('Do you want to default to all business days of week in the schedule (Monday - Friday)? (Type "y" or "n"): ')
    if (useAllWeekdays == 'y' or useAllWeekdays == 'n'):
        break

daysOfWeek = []
    
if (useAllWeekdays == 'n'):
    listOfDays = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]
    print('Accepted days: "Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"')
    
    while True:
        print(f'Current selected days of week {daysOfWeek}')
        dayEntered = input('Type in a day or hit "Enter" immediately to proceed with selected days of week. (Finishing with empty list defaults to all business days): ')
        
        if not dayEntered:
            break 
        
        if dayEntered in listOfDays and dayEntered not in daysOfWeek:
            daysOfWeek.append(dayEntered)
        

if len(daysOfWeek) == 0:
    daysOfWeek = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']

print(f'\nSelected days of week: {daysOfWeek}.\n')

# Setup the time for schedule to occur on each selected day
print('Minutes into the days reference: 540 = 9am, 600 = 10am, 660 = 11am, 720 = 12pm, 780 = 1pm, 840 = 2pm, 900 = 3pm, 960 = 4pm, 1020 = 5pm.')
while True:
    minutesInput = input('Enter the minutes into the day for each automation to be scheduled at: ')
    try:
        minutesIntoDays = int(minutesInput)
        if (minutesIntoDays >= 0 and minutesIntoDays < 1440):
            break 
    except ValueError:
        print(f'{minutesInput} is not a valid value.')
    print(f'Please enter an integer from 0 - 1439.')
        
print(f'\nSelected minutes into days: {minutesIntoDays}.\n')
    
# Setup days in arrears for rent (one condition per rule)
print('By default all automations will be updated with rules for 3, 5 and 7 days in rent arrears and all with the same messageTemplateId for that customer (as read from csv file).')
while True:
    useDefaultRules = input('Do you want to use the default? (Type "y" or hit "Enter" immediately to use defaults. Enter "n" to define your own days): ')
    if not useDefaultRules or useDefaultRules == 'y' or useDefaultRules == 'n':
        break 
        
daysInArrears = []

if (useDefaultRules == 'n'):
    while True:
        print(f'Current days in arrears {daysInArrears}')
        daysInArrearsInput = input('Type in a number or hit "Enter" immediately to proceed with selected days in arrears values. (Empty list reverts to using default values): ')
        
        if not daysInArrearsInput:
            break 
            
        try:
            daysInArrearsInt = int(daysInArrearsInput)
            if daysInArrearsInt not in daysInArrears:
                daysInArrears.append(daysInArrearsInt)
        except ValueError:
            print(f'{daysInArrearsInput} is not a valid integer value')
    
if len(daysInArrears) == 0:
    daysInArrears = [3, 5, 7]
else:
    daysInArrears = sorted(daysInArrears)

scheduleSummary = f"""SELECTED VALUES:
    Days of week: {daysOfWeek}
    Minutes into days: {minutesIntoDays}
    Days in arrears: {daysInArrears}
    """.format(daysOfWeek, minutesIntoDays, daysInArrears)

print('\n**CHECK VALUES ARE EXPECTED**')
print(scheduleSummary)
input('Hit "Enter" to continue to authenticating each customer. To re-execute the script and start again, close the program.') 
print(divider)
# Out:
# ********************************************************************************
#
# CONFIGURE AUTOMATION RULES AND SCHEDULES:
# Do you want to default to all business days of week in the schedule (Monday - Friday)? (Type "y" or "n"):  y
# Selected days of week: ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'].
#
# Minutes into the days reference: 540 = 9am, 600 = 10am, 660 = 11am, 720 = 12pm, 780 = 1pm, 840 = 2pm, 900 = 3pm, 960 = 4pm, 1020 = 5pm.
# Enter the minutes into the day for each automation to be scheduled at:  975
# Selected minutes into days: 975.
#
# By default all automations will be updated with rules for 3, 5 and 7 days in rent arrears and all with the same messageTemplateId for that customer (as read from csv file).
# Do you want to use the default? (Type "y" or hit "Enter" immediately to use defaults. Enter "n" to define your own days):
# **CHECK VALUES ARE EXPECTED**
# SELECTED VALUES:
#     Days of week: ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
#     Minutes into days: 975
#     Days in arrears: [3, 5, 7]
# Hit "Enter" to continue to authenticating each customer. To re-execute the script and start again, close the program.
# ********************************************************************************

# %% [markdown]
# ## 7. Update all Automations with a Schedule (configured in step 4)
# ----------------

# %%
# Patch automations with a schedule
print(divider)
print('\nPATCHING EACH AUTOMATION WITH A SCHEDULE:')
    
def ConstructCondition(daysInArrears: int):
    return {
        "Type": "TenantArrears", 
        "ArrearsType": "rent", 
        "DaysInArrears": daysInArrears
    }

def ConstructAction(templateId: str):
    return {
        "Type": "SendTemplateMessage",
        "MessageTemplateId": templateId
    }

def ConstructRule(daysInArrears: int, templateId: str):
    return {
        "Conditions": [ConstructCondition(daysInArrears)],
        "Actions": [ConstructAction(templateId)]
    }

def ConstructRules(daysInArrearsList: list, templateId: str):
    rules = [] 
    for daysInArrearsNum in daysInArrearsList:
        rules.append(ConstructRule(daysInArrearsNum, templateId))
    return rules 

@PropertyMeHttpRequestExceptionHandler(True)
def PatchAutomationRequest(requestSession: Session, automationId: str, json: dict):
    global patchAutomationEndpointUrl
    return requestSession.patch(f'{patchAutomationEndpointUrl}/{automationId}', json=json)

def PatchAutomation(requestSession: Session, automationId: str, templateId: str):
    patchAutomationData = {
        "Name": "Load test Automation",
        "Rules": ConstructRules(daysInArrears, templateId),
        "Schedule": {
            "DaysOfWeek": daysOfWeek,
            "MinutesIntoDays": minutesIntoDays
        }
    }
    
    patchResp = PatchAutomationRequest(requestSession, automationId, patchAutomationData)
    
    if patchResp is not None:
        print(f"Automation PATCH for ID: '{automationId}'")
        
# functional approach is a neat way to easily propogate PATCHs for users in a dataframe
def PatchAuto(s: pd.Series):
    global pmeHandler
    session = pmeHandler.Sessions[0].Current
    PatchAutomation(session, s.AutomationId, s.MessageTemplateId)
    return

print(f"PATCH requests to be made to base url '{patchAutomationEndpointUrl}/<automationId>'")
print(f"Preparing to update automations with schedules for {customers.shape[0]} customers...")

customerWide.apply(PatchAuto, axis=1)

print(divider)
ConsoleHelpers.PreventImmediateConsoleClose('Completed. Hit "Enter" immediately to close console.')
# Out:
# ********************************************************************************
#
# PATCHING EACH AUTOMATION WITH A SCHEDULE:
# PATCH requests to be made to base url 'https://app-dev2.sandbox.propertyme.com/api/automation/automations/<automationId>'
# Preparing to update automations with schedules for 1 customers...
# Automation PATCH for ID: '1f8ad0bb-0e06-49c8-86c6-8897ec946bfd'
# Automation PATCH for ID: 'f906b80b-1cbf-4c77-972a-fc6c7e155d71'
# Automation PATCH for ID: '549e18f8-bdf4-4a55-97e6-6157a9052a84'
# Automation PATCH for ID: 'e6d5a412-91ec-4f3c-a787-c167a5b545fb'
# Automation PATCH for ID: '78b26f7d-3f5e-4e93-aefb-9d811ed277a3'
# Automation PATCH for ID: '000596c7-9a7e-47e6-afeb-3b4879d083e3'
# Automation PATCH for ID: '924b8bb7-e0d8-4379-bae1-774d0ed6e1a6'
# Automation PATCH for ID: '911eb1ed-4161-4dab-92b8-b2173f7cc228'
# Automation PATCH for ID: '84c1b16e-1d5c-4a6f-a165-11d702a10a25'
# Automation PATCH for ID: 'cf00d6d4-b4d8-4f55-a2cb-5998160b26bc'
# Automation PATCH for ID: '58e3c809-a855-4cdd-a8c7-5d66be144eea'
# Automation PATCH for ID: 'bec979ff-b4b8-4f3d-a91e-ca861b458730'
# Automation PATCH for ID: 'c73673d8-2e2d-4ba8-bac0-a86385f687b2'
# Automation PATCH for ID: '6177399a-ebaf-4be6-9930-1f0b79b4b86c'
# Automation PATCH for ID: '43667377-af16-4a13-803a-c7825ef3cdca'
# Automation PATCH for ID: '734581fc-e351-479e-b9a8-0621329d7e3b'
# Automation PATCH for ID: '9f3060c2-6e0f-4cdf-afd2-47adbcb368d4'
# Automation PATCH for ID: 'fa807fa1-ad02-4197-89e7-fa8bc8468a2c'
# Automation PATCH for ID: '5f151787-71f6-4037-8333-68313234914f'
# Automation PATCH for ID: '37a7d700-43a0-4ad8-a067-dc097ac47728'
# Automation PATCH for ID: '37a8e5ba-33ce-4033-acf2-7e33fefa28ae'
# Automation PATCH for ID: '7dd61af1-25e9-45ed-987c-7c9b98fafbce'
# Automation PATCH for ID: 'cbce2a2c-69e3-43c8-93fb-a1baef1d5aa9'
# Automation PATCH for ID: '4dce5b71-7678-4336-bd93-3aeb822e7ac3'
# Automation PATCH for ID: '9f4743c9-fc6b-444f-8a47-247afebf9633'
# Automation PATCH for ID: '643b2197-ee17-4dfc-a142-8b580a5c1018'
# Automation PATCH for ID: '95f45495-b2d8-445a-93e8-c9823b7c225e'
# Automation PATCH for ID: '1a20d591-7f19-4147-8100-942eb6768be8'
# Automation PATCH for ID: 'cf036689-0e65-4c50-ae4d-90cd4e0cc019'
# Automation PATCH for ID: '4d648423-f257-404e-9b0d-f761d7cc4cbf'
# Automation PATCH for ID: '9faae361-e914-4d50-8c47-81235365e156'
# Automation PATCH for ID: '28d55246-8f2b-46ea-b052-bcf459564b7c'
# Automation PATCH for ID: 'b08c0227-1c2d-4c71-b5aa-5f026f1d4615'
# Automation PATCH for ID: '599c88fb-556d-4746-9504-4274b3fc9d3f'
# Automation PATCH for ID: '9367f0bc-d8f5-4251-80ac-724ba7c01362'
# Automation PATCH for ID: '8dabf612-f936-456a-b3e2-05b8397cb1ef'
# Automation PATCH for ID: '4117d3da-1a7d-4c0f-a67c-f4935bdf4a3f'
# Automation PATCH for ID: '0f274a3e-7440-401b-8ae1-21b2bf2a4d7e'
# Automation PATCH for ID: 'effca01b-4373-4dc0-963d-e2e90a98423b'
# Automation PATCH for ID: 'fec4a231-9d97-4816-8fc7-91ec47d32f41'
# Automation PATCH for ID: 'cc8b7ebb-9200-45b9-b595-2630d3553cdb'
# Automation PATCH for ID: 'e6d447ec-477f-4ef9-bb11-f172ac0e933b'
# Automation PATCH for ID: '81c52190-cf8e-44a1-b895-49d62ea61fe0'
# Automation PATCH for ID: 'd1c737ea-d979-4b05-bddf-dd126481c0fd'
# Automation PATCH for ID: '34fae356-3e47-469e-9d8f-1ea861e03f20'
# Automation PATCH for ID: 'cb8d4c07-8c4d-4e18-9f3e-deb07bc3aff3'
# Automation PATCH for ID: '086bc6a0-0cea-4510-8c96-e301e60958f4'
# Automation PATCH for ID: '85895133-f82a-4b49-8d66-ede9ce08b8e7'
# Automation PATCH for ID: '5216e263-c83c-4c9d-9a85-5fc75e776251'
# Automation PATCH for ID: '448eee7a-2112-4310-a8ea-291ad28e0716'
# Automation PATCH for ID: '4148864c-654a-446c-aa2e-e464fbd41452'
# Automation PATCH for ID: 'd3b05aa2-9356-451c-9d85-468159da484c'
# Automation PATCH for ID: '046bb07a-3c54-43fb-9e5d-71cf0829adc5'
# Automation PATCH for ID: 'dec3e2d1-2942-4ff2-b07f-1338004c979e'
# Automation PATCH for ID: '3159f04e-e7e2-4f21-929b-7c53cfe329ac'
# Automation PATCH for ID: 'f45f8a8f-82f4-44ce-aa62-7fd5cb6e0d4b'
# Automation PATCH for ID: 'a4b8fbfd-b896-420e-9854-44805fe43dd1'
# Automation PATCH for ID: 'c4a838e8-81b7-4eac-bd69-fec192850e70'
# Automation PATCH for ID: '2e8564a6-e158-4d24-8707-d1ee13d102a1'
# Automation PATCH for ID: 'f1e5ffd3-ca5a-45a7-baa5-70948f25b519'
# Automation PATCH for ID: '1a8c80ce-79d8-47dc-bdb9-c6d84a063f83'
# Automation PATCH for ID: 'c73a1d14-d88c-40bf-a28c-ebe793270c26'
# Automation PATCH for ID: 'a7d57a01-4b3a-4d83-a8b7-52aa875ec7d2'
# Automation PATCH for ID: '07a2650c-8856-4316-84a2-fd722cfcfcc5'
# Automation PATCH for ID: '55121453-d0ee-475f-b5e5-9eb4e512c10d'
# Automation PATCH for ID: '19498fd7-158e-4fc9-97cd-0be3abda62a9'
# Automation PATCH for ID: 'a4c583bf-11f0-4c44-ae2a-297956d5db8b'
# Automation PATCH for ID: '36a67262-b8e5-475b-8dc7-c69d45c27818'
# Automation PATCH for ID: '1e2ff184-baf6-48f5-a12a-2dad66de17b8'
# Automation PATCH for ID: '50075579-12ff-4c59-8f55-ce5f695fd509'
# Automation PATCH for ID: '2b47b19c-94c5-41e1-a4a9-a5b5333a1b0f'
# Automation PATCH for ID: 'd15cf081-7050-46e2-91f6-6830a1ba99fe'
# Automation PATCH for ID: 'e3963f92-1753-40ab-bf24-239ed0031e0a'
# Automation PATCH for ID: '336a4b28-12ae-41c7-863d-ae5db5bb97f3'
# Automation PATCH for ID: '45023a86-b2d2-48a2-b7ce-37a5757f1002'
# Automation PATCH for ID: '7f7b3311-6619-47fc-bd82-2403b41369c4'
# Automation PATCH for ID: 'a0bcec30-6e1a-4c56-9cc7-4b87dcc41f66'
# Automation PATCH for ID: 'a2d7b677-58db-44b5-9185-ebe012b66b05'
# Automation PATCH for ID: 'ea82c987-f6b5-4ae7-834a-df56be55f3eb'
# Automation PATCH for ID: 'b9697cdb-16e8-4696-952c-9898e2cd7fb6'
# Automation PATCH for ID: '23ace9ee-e0d5-416c-95b8-48fb781a30ff'
# Automation PATCH for ID: '54f3cee7-d28d-4745-84b0-8b180de49cf0'
# Automation PATCH for ID: 'c46e7f77-bb2a-4724-add8-d401b38ff686'
# Automation PATCH for ID: 'c8b83185-760a-410c-a16e-474444964075'
# Automation PATCH for ID: '90e6c2ec-3c53-4f12-a3be-4c8a4601f815'
# Automation PATCH for ID: 'cf1690b4-0dbb-4671-87d8-ff73893fa330'
# Automation PATCH for ID: '2eb1ffa4-156f-4b4e-b79e-5c799eee619c'
# Automation PATCH for ID: '0fa2718f-5a63-4c8c-9b36-dd57d37985f9'
# Automation PATCH for ID: '5fbc78a1-2c85-472d-805d-7b8bafed88fa'
# Automation PATCH for ID: '1ccd0f67-d728-497e-abe1-6514adf6f2c7'
# Automation PATCH for ID: 'bc2f60a2-05ee-48aa-8c2b-49f82296212f'
# Automation PATCH for ID: 'db6d58e1-c44f-4f7e-aeac-126a2a357b79'
# Automation PATCH for ID: '3b1d218f-3f5e-4fe6-838a-c8e46a81f0fd'
# Automation PATCH for ID: '53a4ad33-59e0-4c50-ab8f-1c3f39bb36b6'
# Automation PATCH for ID: 'b7ab0e2b-68b8-41ff-85b0-c5623f81516a'
# Automation PATCH for ID: '9d017532-c96a-4370-bfa1-0ad7cd523284'
# Automation PATCH for ID: '50e9984f-b569-4599-ac3f-c3b0368559fc'
# Automation PATCH for ID: '6d7da892-6adb-4b98-8132-274285f85004'
# Automation PATCH for ID: 'c7d4c2b7-1418-4456-9c25-7f1f38c09f37'
# Automation PATCH for ID: 'b548ea2e-10ce-44f0-9840-8a85767374b1'
# Automation PATCH for ID: '6a9db73d-efcd-49a7-b27c-33b7183656a1'
# Automation PATCH for ID: 'e565ea6f-dcd6-47a2-9740-ec9f0b1198e5'
# Automation PATCH for ID: 'd3136103-c8da-45d6-a5d8-cb919a477318'
# Automation PATCH for ID: '4dca9582-039a-4633-90e7-398ce8a95a0c'
# Automation PATCH for ID: '590449bf-6946-454c-950e-9b1f57d7d3cf'
# Automation PATCH for ID: '13f1b127-f978-4f63-a76b-1d7b2a9b1592'
# Automation PATCH for ID: '6dec8a1f-fa82-4a25-9e26-c30543b21ec7'
# Automation PATCH for ID: '55d921ed-a318-4abd-8d12-78212ec62151'
# Automation PATCH for ID: '8abade58-9b2b-4d84-b8b5-a96dc111e6ef'
# Automation PATCH for ID: 'c9111b8c-0da9-4035-b0a2-c30f89b34c5b'
# Automation PATCH for ID: '9e9cbf4d-122d-42f5-b6e7-e8bab71d04aa'
# Automation PATCH for ID: 'ba99a4c6-8722-4088-87f5-30d645e9632f'
# Automation PATCH for ID: 'dc2badc5-b2ab-4dc2-b9b0-2d0bd954a358'
# Automation PATCH for ID: '5c78fa71-fb1d-48f7-be5a-fd656d8756ff'
# Automation PATCH for ID: '3c0042a2-164a-4110-822a-370de3d5689e'
# Automation PATCH for ID: '9b3fbb2b-7734-4ab2-bcfa-0d04d2eb67e8'
# Automation PATCH for ID: '505cf6e6-72e8-4ca0-8679-a2cd11a114a1'
# Automation PATCH for ID: 'efa9f6ae-4f72-4f60-9c32-7aa6be484d65'
# Automation PATCH for ID: '54871cc3-2fd9-4c66-a03d-1fbb9584ae86'
# Automation PATCH for ID: '9d6a9cf3-c9b6-44c9-946c-499843b27755'
# Automation PATCH for ID: '9edf4bee-5339-45d5-98f8-7c44ce402e76'
# Automation PATCH for ID: '249a1a43-1a35-4387-8130-0dad5c718a74'
# Automation PATCH for ID: 'f990b026-abe4-4a45-bd8f-f451d9947aa2'
# Automation PATCH for ID: 'e68c8308-6c9f-4a4a-9ab9-6a1e469a312a'
# Automation PATCH for ID: 'a9aa411a-c4a2-4c0f-bd9a-18a4e1c7b1d6'
# Automation PATCH for ID: '19261f77-8e3b-40bc-98ca-26effde647f8'
# Automation PATCH for ID: 'b71b3484-bf4d-4a7d-9671-d50adf9d7550'
# Automation PATCH for ID: 'c6073de2-5516-402f-b7d8-4f2e74f0be23'
# Automation PATCH for ID: 'e29f1d49-39d3-40f1-84bd-046f11e412e1'
# Automation PATCH for ID: 'daeacbc8-a53f-4856-9308-a7cef76b6175'
# Automation PATCH for ID: 'd2eb0b3e-a0c9-4fbc-a3ea-f43f3078bacb'
# Automation PATCH for ID: 'c15817e1-c6a1-44d9-9d70-1479858a01fc'
# Automation PATCH for ID: 'd01e688d-354f-48da-8752-9d1ab1391e25'
# Automation PATCH for ID: '5ee83674-7fef-439e-8661-8268e5987861'
# Automation PATCH for ID: 'e0b9c8fc-9b5d-4806-aec9-8e275c28d416'
# Automation PATCH for ID: '390b02f8-4877-41a4-b609-c988fa71c6a1'
# Automation PATCH for ID: 'bd106919-8cb8-4e8d-931e-8cf79ec124d3'
# Automation PATCH for ID: '002deda7-e7c2-4cd8-8f6c-e7a670596621'
# Automation PATCH for ID: 'd523f56e-3669-4120-acf5-09132442e9f9'
# Automation PATCH for ID: '67668d0f-0eae-4412-9a5d-6b23bc329a37'
# Automation PATCH for ID: '96266323-eca5-4f77-a994-5ef0da9821d6'
# Automation PATCH for ID: '884db0cd-ed82-45ec-9ef2-7b7a1aa38ca8'
# Automation PATCH for ID: 'e248827f-42a7-4521-8731-e3262d6a0f90'
# Automation PATCH for ID: 'e558d679-6860-4897-a4af-1f0eb4e0bd70'
# Automation PATCH for ID: '6db98391-a059-4b3c-a9bb-1815f36a4b7c'
# Automation PATCH for ID: 'db141eac-820f-42a0-90ee-e631410aaa96'
# Automation PATCH for ID: '11a1dfc4-48fb-4bc2-b1b5-508362e0ea39'
# Automation PATCH for ID: '60cc2b4f-5e35-452e-a312-a455299bb2b7'
# Automation PATCH for ID: '52e3f4f6-7ff3-43e9-9621-02766a823f58'
# Automation PATCH for ID: 'c9958140-a0a2-43d9-b035-10db32dd0443'
# Automation PATCH for ID: '47e1daa6-db68-40cc-b9fe-6e11ebe2fdf3'
# Automation PATCH for ID: '9ea74bf6-88fe-4f48-950d-528d1e6c3881'
# Automation PATCH for ID: '4aafd484-c588-4797-b42f-8b3083a53112'
# Automation PATCH for ID: 'b597f414-8869-4e5a-be11-ec1da2fc13f8'
# Automation PATCH for ID: '80fe5305-e444-48cd-8be7-970217037cba'
# Automation PATCH for ID: '0a8a962f-be22-404c-8b34-4e83e41c7b66'
# Automation PATCH for ID: '0ec14dfa-1578-4538-bfb1-802239b7055d'
# Automation PATCH for ID: 'd4800386-8dfd-4a68-a23a-72e26a585131'
# Automation PATCH for ID: '047af455-fb9c-404f-b64e-51c19118f1f8'
# Automation PATCH for ID: '54c3f796-cc41-4a5e-986e-2693bad02402'
# Automation PATCH for ID: '6b4a8c9a-d412-4135-8b22-58d98fc0d44a'
# Automation PATCH for ID: '5879a6c4-0e52-4e67-86ef-0f00425bfe06'
# Automation PATCH for ID: '50ceacc6-add4-428d-9efc-a8acf5040804'
# Automation PATCH for ID: '2908fd66-cb74-4791-b5cd-d1fe3c149d6b'
# Automation PATCH for ID: '79a6d57e-e651-4bdc-bef6-6e415e45eec6'
# Automation PATCH for ID: 'e8200aa3-2abf-4202-8dd4-90d0aba74110'
# Automation PATCH for ID: '297f7619-7fd6-48e4-87dc-a558f880baba'
# Automation PATCH for ID: '36dae47f-207b-4dc5-bb62-2f1dcc5617d2'
# Automation PATCH for ID: 'bb96e11e-6f6f-4cd9-ad9e-26bf4e1337c2'
# Automation PATCH for ID: '51da4780-fa4b-4d1e-b11c-6ed7e7c1b6fe'
# Automation PATCH for ID: '76816e7a-197b-4afd-bd2c-9be8fe52bacd'
# Automation PATCH for ID: '9706284a-9cfa-4149-a1d7-fd6aec302223'
# Automation PATCH for ID: '731a0483-8c12-4d93-9398-d547fc065307'
# Automation PATCH for ID: '2470da51-1c62-42d1-90f8-88242014a602'
# Automation PATCH for ID: '84a6a985-8d64-42c4-aac4-925545c4db90'
# Automation PATCH for ID: 'b24298b7-f87e-4489-86dc-563e3f590985'
# Automation PATCH for ID: '2ad08afc-c8cf-465d-8f39-64252dbca868'
# Automation PATCH for ID: 'f2c868dc-ece5-4631-85c9-6d0f4ba564ca'
# Automation PATCH for ID: 'ade5572a-dcdb-418f-aadf-3c8d9ae28a8d'
# Automation PATCH for ID: '3ee72948-f5fa-4572-aa8a-ebd44ec883be'
# Automation PATCH for ID: 'c0c78cc5-a4d4-4eba-b77d-c8e7fded1086'
# Automation PATCH for ID: '527af38b-2a67-477a-99c3-78157394c43b'
# Automation PATCH for ID: '645b3a30-d602-4309-836c-24c1210861ef'
# Automation PATCH for ID: 'b4194250-c333-4f2b-b668-47c564a1edd4'
# Automation PATCH for ID: 'c0e6d881-0da4-4bc6-a659-ec537ba24ace'
# Automation PATCH for ID: '4b602b95-cb2d-48bb-84e5-ab8a96402b49'
# Automation PATCH for ID: 'f5c3945f-27ac-4638-88e2-c3deb87a73cc'
# Automation PATCH for ID: 'f9e5ea8e-6fb2-4116-a803-304061298154'
# Automation PATCH for ID: 'ede00641-f46c-4660-83be-7d9d48f31388'
# Automation PATCH for ID: 'bc127aeb-c1bb-4a3a-a5bf-ca117ec35fb5'
# Automation PATCH for ID: 'b89b9a51-991b-4255-a290-18a4135c26a6'
# Automation PATCH for ID: '065d953a-7b11-41d7-a3ed-66405aec7f4e'
# Automation PATCH for ID: '38a0c603-acb5-4621-ae2b-f2f231213309'
# Automation PATCH for ID: '3b93e558-10ed-4978-9893-ae6b9e7d2f49'
# Automation PATCH for ID: 'cf0d1627-0eb5-4766-b618-c9f6bcc5c58f'
# Automation PATCH for ID: '7b0ece21-b818-43b8-8636-43706a36e12a'
# Automation PATCH for ID: '656ae7ca-2d3a-4d5e-b147-ad7d6a36d112'
# Automation PATCH for ID: 'd277345f-63f2-4e01-b106-86fb7383f7d5'
# Automation PATCH for ID: '6f97159d-45a6-4c3b-ae75-f3c1578cbf50'
# Automation PATCH for ID: '6d5444b5-6771-4d24-a571-4d3b80dfa7fa'
# ********************************************************************************
#
#
# Completed. Hit "Enter" immediately to close console.
# Hit "Enter" with no value to close console.
